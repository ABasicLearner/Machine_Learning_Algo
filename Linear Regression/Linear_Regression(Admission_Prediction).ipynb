# %%
import pickle
import numpy as np 
import pandas as pd
from sklearn.preprocessing import StandardScaler 
from sklearn.linear_model import Ridge, Lasso, ElasticNet, RidgeCV, LassoCV, ElasticNetCV, LinearRegression
from sklearn.model_selection import train_test_split
from ydata_profiling import ProfileReport

# %%
df = pd.read_csv("Admission_Prediction.csv")

# %%
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1      337.0        118.0                4.0  4.5  4.5  9.65
# 1             2      324.0        107.0                4.0  4.0  4.5  8.87
# 2             3        NaN        104.0                3.0  3.0  3.5  8.00
# 3             4      322.0        110.0                3.0  3.5  2.5  8.67
# 4             5      314.0        103.0                2.0  2.0  3.0  8.21
# ..          ...        ...          ...                ...  ...  ...   ...
# 495         496      332.0        108.0                5.0  4.5  4.0  9.02
# 496         497      337.0        117.0                5.0  5.0  5.0  9.87
# 497         498      330.0        120.0                5.0  4.5  5.0  9.56
# 498         499      312.0        103.0                4.0  4.0  5.0  8.43
# 499         500      327.0        113.0                4.0  4.5  4.5  9.04
#
#      Research  Chance of Admit
# 0           1             0.92
# ...

# %% [markdown]
# GRE Score: This is the score of the applicant on the Graduate Record Examination (GRE). The GRE is a standardized test that is used for graduate school admissions.
#
# TOEFL Score: This is the score of the applicant on the Test of English as a Foreign Language (TOEFL). The TOEFL is a standardized test that is used to measure English proficiency for international students.
#
# University Rating: This is a subjective rating of the university that the applicant is applying to. The rating is on a scale of 1 to 5, with 1 being the lowest and 5 being the highest.
#
# SOP: This is the applicant's Statement of Purpose. The SOP is a personal statement that describes the applicant's academic and professional goals.
#
# LOR: This is the applicant's Letter(s) of Recommendation. The LOR is a letter from a professor or other academic advisor who can attest to the applicant's academic abilities and potential.
#
# CGPA: This is the applicant's cumulative grade point average (GPA). The GPA is a measure of the applicant's academic performance in college.
#
# Research: This is a binary variable that indicates whether or not the applicant has research experience.
#
# Chance of Admit: This is the predicted probability of the applicant being admitted to the graduate program.

# %%
pf = ProfileReport(df)
pf.to_widgets()
# Out:
# ...
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %%
df['GRE Score'] = df['GRE Score'].fillna(df['GRE Score'].mean())

# %%
df['TOEFL Score'] = df['TOEFL Score'].fillna(df['TOEFL Score'].mean())

# %%
df['University Rating'] = df['University Rating'].fillna(df['University Rating'].mean())

# %%
df.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  500.000000  500.000000   500.000000         500.000000  500.000000
# mean   250.500000  316.558763   107.187755           3.121649    3.374000
# std    144.481833   11.103952     6.051338           1.128802    0.991004
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    125.750000  309.000000   103.000000           2.000000    2.500000
# 50%    250.500000  316.558763   107.000000           3.000000    3.500000
# 75%    375.250000  324.000000   112.000000           4.000000    4.000000
# max    500.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR        CGPA    Research  Chance of Admit
# count  500.00000  500.000000  500.000000        500.00000
# mean     3.48400    8.576440    0.560000          0.72174
# std      0.92545    0.604813    0.496884          0.14114
# min      1.00000    6.800000    0.000000          0.34000
# ...

# %%
df.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
df.drop(columns = ['Serial No.'], inplace = True)

# %%
df
# Out:
#       GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  Research  \
# 0    337.000000        118.0                4.0  4.5  4.5  9.65         1
# 1    324.000000        107.0                4.0  4.0  4.5  8.87         1
# 2    316.558763        104.0                3.0  3.0  3.5  8.00         1
# 3    322.000000        110.0                3.0  3.5  2.5  8.67         1
# 4    314.000000        103.0                2.0  2.0  3.0  8.21         0
# ..          ...          ...                ...  ...  ...   ...       ...
# 495  332.000000        108.0                5.0  4.5  4.0  9.02         1
# 496  337.000000        117.0                5.0  5.0  5.0  9.87         1
# 497  330.000000        120.0                5.0  4.5  5.0  9.56         1
# 498  312.000000        103.0                4.0  4.0  5.0  8.43         0
# 499  327.000000        113.0                4.0  4.5  4.5  9.04         0
#
#      Chance of Admit
# 0               0.92
# 1               0.76
# ...

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %%
scaler = StandardScaler()

# %%
arr = scaler.fit_transform(X)
arr
# Out:
# array([[ 1.84274116e+00,  1.78854223e+00,  7.78905651e-01, ...,
#          1.09894429e+00,  1.77680627e+00,  8.86405260e-01],
#        [ 6.70814288e-01, -3.10581135e-02,  7.78905651e-01, ...,
#          1.09894429e+00,  4.85859428e-01,  8.86405260e-01],
#        [ 5.12433309e-15, -5.27312752e-01, -1.07876604e-01, ...,
#          1.73062093e-02, -9.54042814e-01,  8.86405260e-01],
#        ...,
#        [ 1.21170361e+00,  2.11937866e+00,  1.66568791e+00, ...,
#          1.63976333e+00,  1.62785086e+00,  8.86405260e-01],
#        [-4.10964364e-01, -6.92730965e-01,  7.78905651e-01, ...,
#          1.63976333e+00, -2.42366993e-01, -1.12815215e+00],
#        [ 9.41258951e-01,  9.61451165e-01,  7.78905651e-01, ...,
#          1.09894429e+00,  7.67219636e-01, -1.12815215e+00]])

# %%
df1 = pd.DataFrame(arr)
df1
# Out:
#                 0         1         2         3         4         5         6
# 0    1.842741e+00  1.788542  0.778906  1.137360  1.098944  1.776806  0.886405
# 1    6.708143e-01 -0.031058  0.778906  0.632315  1.098944  0.485859  0.886405
# 2    5.124333e-15 -0.527313 -0.107877 -0.377773  0.017306 -0.954043  0.886405
# 3    4.905178e-01  0.465197 -0.107877  0.127271 -1.064332  0.154847  0.886405
# 4   -2.306679e-01 -0.692731 -0.994659 -1.387862 -0.523513 -0.606480 -1.128152
# ..            ...       ...       ...       ...       ...       ...       ...
# 495  1.392000e+00  0.134360  1.665688  1.137360  0.558125  0.734118  0.886405
# 496  1.842741e+00  1.623124  1.665688  1.642404  1.639763  2.140919  0.886405
# 497  1.211704e+00  2.119379  1.665688  1.137360  1.639763  1.627851  0.886405
# 498 -4.109644e-01 -0.692731  0.778906  0.632315  1.639763 -0.242367 -1.128152
# 499  9.412590e-01  0.961451  0.778906  1.137360  1.098944  0.767220 -1.128152
#
# [500 rows x 7 columns]

# %%
repo = df1.profile_report()
repo.to_widgets()
# Out:
# ...
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %%
df1.describe()
# Out:
#                   0             1             2             3             4  \
# count  5.000000e+02  5.000000e+02  5.000000e+02  5.000000e+02  5.000000e+02
# mean   4.350520e-15  9.419132e-16  5.608847e-16  2.926548e-16 -1.332268e-17
# std    1.001002e+00  1.001002e+00  1.001002e+00  1.001002e+00  1.001002e+00
# min   -2.394225e+00 -2.512331e+00 -1.881441e+00 -2.397950e+00 -2.686789e+00
# 25%   -6.814090e-01 -6.927310e-01 -9.946589e-01 -8.828175e-01 -5.235128e-01
# 50%    5.124333e-15 -3.105811e-02 -1.078766e-01  1.272712e-01  1.730621e-02
# 75%    6.708143e-01  7.960330e-01  7.789057e-01  6.323155e-01  5.581253e-01
# max    2.113186e+00  2.119379e+00  1.665688e+00  1.642404e+00  1.639763e+00
#
#                   5             6
# count  5.000000e+02  5.000000e+02
# mean   3.091971e-15 -2.202682e-16
# std    1.001002e+00  1.001002e+00
# min   -2.940115e+00 -1.128152e+00
# 25%   -7.430227e-01 -1.128152e+00
# 50%   -2.720919e-02  8.864053e-01
# 75%    7.672196e-01  8.864053e-01
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif_df = pd.DataFrame()

# %%
vif_df['vif'] = [variance_inflation_factor(arr, i) for i in range(arr.shape[1])]

# %%
vif_df['feature'] = X.columns

# %%
vif_df
# Out:
#         vif            feature
# 0  4.153268          GRE Score
# 1  3.792866        TOEFL Score
# 2  2.508768  University Rating
# 3  2.775750                SOP
# 4  2.037308                LOR
# 5  4.651670               CGPA
# 6  1.459311           Research

# %%
# vif of each column is < 10
# No need of dimension reduction

# %%
x_train, x_test, y_train, y_test = train_test_split(arr, y, test_size=0.2, random_state=45)

# %%
lr = LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
pickle.dump(lr, open('admission_lr_model.pickle', 'wb'))

# %%
admission_lr_model = pickle.load(open('admission_lr_model.pickle', 'rb'))

# %%
data = scaler.transform([[337, 118, 4, 4.5, 4.5, 9.65, 1]])
# Out:
# C:\Users\PRITI CHAUDHARY\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
admission_lr_model.predict(data)
# Out:
# array([0.95235481])

# %%
R_square = lr.score(x_test, y_test)
R_square
# Out:
# 0.8465865826608236

# %%
#Adjusted R square
def adj_r2(x, y):
    r2 = lr.score(x, y)
    n = x.shape[0]
    p = x.shape[1]
    adjusted_r2 = 1-(1-r2)*(n-1)/(n-p-1)
    return adjusted_r2

# %%
adj_r2(x_test, y_test)
# Out:
# 0.8349138226458863

# %%
lr.coef_
# Out:
# array([0.01837968, 0.01646921, 0.00409134, 0.0067127 , 0.01447583,
#        0.07351827, 0.01127956])

# %%
lr.intercept_
# Out:
# 0.7216743083246916

# %%
lassocv = LassoCV(cv=10, max_iter=200000, normalize=True)

# %%
lassocv.fit(x_train, y_train)
# Out:
# C:\Users\PRITI CHAUDHARY\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# LassoCV(cv=10, max_iter=200000, normalize=True)

# %%
lassocv.alpha_
# Out:
# 6.140263420444483e-06

# %%
lasso = Lasso(alpha=lassocv.alpha_)
lasso.fit(x_train, y_train)
# Out:
# Lasso(alpha=6.140263420444483e-06)

# %%
lasso.score(x_test, y_test)
# Out:
# 0.8465848295876475

# %%
ridgecv = RidgeCV(alphas=np.random.uniform(0, 10, 50), cv=10, normalize=True)

# %%
ridgecv.fit(x_train, y_train)
# Out:
# C:\Users\PRITI CHAUDHARY\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# C:\Users\PRITI CHAUDHARY\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# ...

# %%
ridgecv.alpha_
# Out:
# 0.3639814126822438

# %%
ridge = Ridge(alpha=ridgecv.alpha_)
ridge.fit(x_train, y_train)
# Out:
# Ridge(alpha=0.3639814126822438)

# %%
ridge.score(x_test, y_test)
# Out:
# 0.8465722841832062

# %%
elasticnetcv = ElasticNetCV(alphas=None, cv=10)
elasticnetcv.fit(x_train, y_train)
# Out:
# ElasticNetCV(cv=10)

# %%
elasticnetcv.alpha_
# Out:
# 0.00024422853880625626

# %%
elasticnetcv.l1_ratio_
# Out:
# 0.5

# %%
elasticnet = ElasticNet(alpha=elasticnetcv.alpha_, l1_ratio=elasticnetcv.l1_ratio_)
elasticnet.fit(x_train, y_train)
# Out:
# ElasticNet(alpha=0.00024422853880625626)

# %%
elasticnet.score(x_test, y_test)
# Out:
# 0.8465442414747892

# %% [markdown]
# all the three lasso, ridge, elasticnet I'm getting same score
#
# That means my model is nicely fitted , stable and not overfitted
